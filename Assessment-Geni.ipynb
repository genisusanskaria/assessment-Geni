# %%
print("enter the number of intergers")
n= int(input())
print("enter the block limit")
k= int (input())
print("enter the elements in block")
for i in range(k,n):
    b= int(arr[i])
    int cos_sum = arr[i] + arr [i-k]
    print(cos_sum)
    print("print maximum sum:")
    max_sum =max(cos_sum)
    print()
# Out:
#   Cell In[6], line 8
#     int cos_sum = arr[i] + arr [i-k]
#         ^
# SyntaxError: invalid syntax

# %%
print('enter the string')
s1 = chr(input())
for i in range(s1):
    if(s1[i]!=s1[i+1])
    s2= s1[i].append(s1[i+1])    
    print(s2)    
    if(s1[i]==s1(i+1))
    print(end="")
